# %% [markdown]
# <a href="https://colab.research.google.com/github/HoangKhaLe/b-i-t-p-n-i-c-m-i-n/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Food
# Out:
# /content/drive/MyDrive/Food

# %%
ls
# Out:
# test/  train/

# %%
import tensorflow as tf
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale = 1.0/255)
flower_train = train_datagen.flow_from_directory(
    './train/',
    target_size= (200, 200),
    batch_size = 16,
    class_mode = 'categorical')
test_data = tf.keras.preprocessing.image.ImageDataGenerator(rescale = 1.0/255)


flower_test = test_data.flow_from_directory(
    './test/', 
    target_size= (200, 200), 
    batch_size = 16,
    class_mode = 'categorical')
# Out:
# Found 500 images belonging to 10 classes.
# Found 514 images belonging to 10 classes.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import layers
model=Sequential()
model.add(Conv2D(32,kernel_size=(3,3),activation='relu',input_shape=(200,200,3),padding='same'))
model.add(MaxPooling2D((2,2),padding='same'))
model.add(Conv2D(64,kernel_size=(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D((2,2),padding='same'))
model.add(Conv2D(128,kernel_size=(3,3),activation='relu',padding='same'))
model.add(MaxPooling2D((2,2),padding='same'))
model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 200, 200, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 100, 100, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 100, 100, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 50, 50, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 50, 50, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 25, 25, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 80000)             0
#
#  dense (Dense)               (None, 128)               10240128
#
#  dense_1 (Dense)             (None, 10)                1290
#
# ...
# Total params: 10,334,666
# Trainable params: 10,334,666
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="rmsprop", loss = "categorical_crossentropy", metrics=["accuracy"])
model.fit(flower_train, epochs=20, batch_size=128)
# Out:
# Epoch 1/20
# 32/32 [==============================] - 47s 1s/step - loss: 2.4715 - accuracy: 0.1080
# Epoch 2/20
# 32/32 [==============================] - 46s 1s/step - loss: 2.2359 - accuracy: 0.2300
# Epoch 3/20
# 32/32 [==============================] - 46s 1s/step - loss: 1.9256 - accuracy: 0.3980
# Epoch 4/20
# 32/32 [==============================] - 46s 1s/step - loss: 1.0319 - accuracy: 0.6660
# Epoch 5/20
# 32/32 [==============================] - 46s 1s/step - loss: 0.8668 - accuracy: 0.8440
# Epoch 6/20
# 32/32 [==============================] - 46s 1s/step - loss: 0.3046 - accuracy: 0.9460
# Epoch 7/20
# 32/32 [==============================] - 46s 1s/step - loss: 0.2552 - accuracy: 0.9400
# Epoch 8/20
# 32/32 [==============================] - 46s 1s/step - loss: 0.0386 - accuracy: 0.9980
# Epoch 9/20
# 32/32 [==============================] - 46s 1s/step - loss: 0.0969 - accuracy: 0.9860
# Epoch 10/20
# ...

# %%
model.save('food.h5')

# %%
from keras.models import load_model
model_food=load_model('food.h5')

# %%
from keras.utils import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np
img = load_img('/content/pho.jpg',target_size = (200,200))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_food.predict(img)
class_name=['Banh beo','Banh bot loc','Banh mi','Bun cha', 'Cha lua', 'Chao long','Com tam', 'Goi cuon', 'Nem chua', 'Pho']
h= int(np.argmax(result,axis=1))
print("Đây là :", class_name[h])
# Out:
# 1/1 [==============================] - 9s 9s/step
# Đây là : Pho

# %%
from keras.utils import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np
img = load_img('/content/ChaLua254.jpg',target_size = (200,200))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_food.predict(img)
class_name=['Banh beo','Banh bot loc','Banh mi','Bun cha', 'Cha lua', 'Chao long','Com tam', 'Goi cuon', 'Nem chua', 'Pho']
h= int(np.argmax(result,axis=1))
print("Đây là :", class_name[h])
# Out:
# 1/1 [==============================] - 0s 84ms/step
# Đây là : Cha lua

# %%
from keras.utils import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np
img = load_img('/content/ChaoLong294.jpg',target_size = (200,200))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_food.predict(img)
class_name=['Banh beo','Banh bot loc','Banh mi','Bun cha', 'Cha lua', 'Chao long','Com tam', 'Goi cuon', 'Nem chua', 'Pho']
h= int(np.argmax(result,axis=1))
print("Đây là :", class_name[h])
# Out:
# 1/1 [==============================] - 0s 54ms/step
# Đây là : Chao long

# %%
from keras.utils import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np
img = load_img('/content/GoiCuon270.jpg',target_size = (200,200))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_food.predict(img)
class_name=['Banh beo','Banh bot loc','Banh mi','Bun cha', 'Cha lua', 'Chao long','Com tam', 'Goi cuon', 'Nem chua', 'Pho']
h= int(np.argmax(result,axis=1))
print("Đây là :", class_name[h])
# Out:
# 1/1 [==============================] - 0s 52ms/step
# Đây là : Goi cuon

# %%
from keras.utils import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np
img = load_img('/content/banhbeo.jpg',target_size = (200,200))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_food.predict(img)
class_name=['Banh beo','Banh bot loc','Banh mi','Bun cha', 'Cha lua', 'Chao long','Com tam', 'Goi cuon', 'Nem chua', 'Pho']
h= int(np.argmax(result,axis=1))
print("Đây là :", class_name[h])
# Out:
# 1/1 [==============================] - 0s 51ms/step
# Đây là : Banh beo

# %%
from keras.utils import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np
img = load_img('/content/banhmi.jpg',target_size = (200,200))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_food.predict(img)
class_name=['Banh beo','Banh bot loc','Banh mi','Bun cha', 'Cha lua', 'Chao long','Com tam', 'Goi cuon', 'Nem chua', 'Pho']
h= int(np.argmax(result,axis=1))
print("Đây là :", class_name[h])
# Out:
# 1/1 [==============================] - 0s 88ms/step
# Đây là : Banh mi

# %%
from keras.utils import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np
img = load_img('/content/BunCha265.jpg',target_size = (200,200))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_food.predict(img)
class_name=['Banh beo','Banh bot loc','Banh mi','Bun cha', 'Cha lua', 'Chao long','Com tam', 'Goi cuon', 'Nem chua', 'Pho']
h= int(np.argmax(result,axis=1))
print("Đây là :", class_name[h])
# Out:
# 1/1 [==============================] - 0s 51ms/step
# Đây là : Bun cha

# %%
from keras.utils import load_img, img_to_array
import matplotlib.pyplot as plt
import numpy as np
img = load_img('/content/329.jpg',target_size = (200,200))
plt.imshow(img)
img=img_to_array(img)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_food.predict(img)
class_name=['Banh beo','Banh bot loc','Banh mi','Bun cha', 'Cha lua', 'Chao long','Com tam', 'Goi cuon', 'Nem chua', 'Pho']
h= int(np.argmax(result,axis=1))
print("Đây là :", class_name[h])
# Out:
# 1/1 [==============================] - 0s 52ms/step
# Đây là : Com tam

# %%
# !jupyter nbconvert --to html "/content/Flower.ipynb"
# Out:
# [NbConvertApp] WARNING | pattern '/content/Flower.ipynb' matched no files
# This application is used to convert notebook files (*.ipynb)
#         to various other formats.
#
#         WARNING: THE COMMANDLINE INTERFACE MAY CHANGE IN FUTURE RELEASES.
#
# Options
# ...
# The options below are convenience aliases to configurable class-options,
# as listed in the "Equivalent to" description-line of the aliases.
# To see all configurable class-options for some <cmd>, use:
#     <cmd> --help-all
#
# --debug
#     set log level to logging.DEBUG (maximize logging output)
#     Equivalent to: [--Application.log_level=10]
# --show-config
#     Show the application's configuration (human-readable format)
#     Equivalent to: [--Application.show_config=True]
# --show-config-json
#     Show the application's configuration (json format)
#     Equivalent to: [--Application.show_config_json=True]
# --generate-config
#     generate default config file
# ...
